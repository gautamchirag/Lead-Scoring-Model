# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv("Data_Science_Internship.csv")

# %%
data
# Out:
#        Unnamed: 0                                           Agent_id status  \
# 0               0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1               1  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2               2  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3               3  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4               4  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# ...           ...                                                ...    ...
# 46603       46603  2306878a9ad9b57686cd623dd285aaa9b25afdf627f651...   LOST
# 46604       46604  327ec29056cc47c24bf922f7dc0f78261dad5c726d7353...   LOST
# 46605       46605  1134c0a7d44fdae1afd7f1f64e2789496784095ca0a050...   LOST
# 46606       46606  8b8b029f1142f5cbc825aa6cbee01406c915c6b055db79...   LOST
# 46607       46607  1ea65ea38f2f574b3875ba895e4ff76b284b7725041612...   LOST
#
#             lost_reason                budget  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46608 entries, 0 to 46607
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      46608 non-null  int64
#  1   Agent_id        46608 non-null  object
#  2   status          46608 non-null  object
#  3   lost_reason     43244 non-null  object
#  4   budget          42908 non-null  object
#  5   lease           44267 non-null  object
#  6   movein          32970 non-null  object
#  7   source          46608 non-null  object
#  8   source_city     46608 non-null  object
#  9   source_country  46608 non-null  object
#  10  utm_source      46608 non-null  object
#  11  utm_medium      46608 non-null  object
#  12  des_city        46608 non-null  object
#  13  des_country     46608 non-null  object
#  14  room_type       23061 non-null  object
#  15  lead_id         46608 non-null  object
# dtypes: int64(1), object(15)
# memory usage: 5.7+ MB

# %%
# Dropping rows with STATUS other than 'WON' or 'LOST'
data = data[data['status'].isin(['WON', 'LOST'])]

# %%
# Set the list of categories for all categorical columns
categories = ['category1', 'category2', 'category3', ..., '9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0']

# Convert all columns to categorical and set categories
for col in data.columns:
    data[col] = pd.Categorical(data[col], categories=categories)

# Replace missing values with '9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0'
data = data.fillna('9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14520\1375049488.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = pd.Categorical(data[col], categories=categories)
# C:\Users\HP\AppData\Local\Temp\ipykernel_14520\1375049488.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = pd.Categorical(data[col], categories=categories)
# C:\Users\HP\AppData\Local\Temp\ipykernel_14520\1375049488.py:6: SettingWithCopyWarning:
# ...

# %%
# Treating all columns as categorical and replacing missing values with '9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0'
data = data.astype('category').fillna('9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0')

# %%
# Selecting relevant features
features = data.drop(['Agent_id', 'status'], axis=1)

# %%
# Splitting the dataset into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, data['status'], test_size=0.3, random_state=42)

# %%
# Import OneHotEncoder
from sklearn.preprocessing import OneHotEncoder

# Define the encoder
encoder = OneHotEncoder()

# Fit and transform the training data
X_train_encoded = encoder.fit_transform(X_train)

# Fit the model on the encoded training data
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_encoded, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Transform the test set using the same encoder used on the training set
X_test_encoded = encoder.transform(X_test)

# Make predictions on the encoded test set
y_pred = model.predict(X_test_encoded)

# %%
# Evaluating the performance of the model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0

# %%
import joblib

# Save the model to a file
joblib.dump(model, 'lead_scoring_model.joblib')
# Out:
# ['lead_scoring_model.joblib']
